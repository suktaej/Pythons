# %% [markdown]
# ### * RNN 주요 레이어 종류
# #### (1) SimpleRNN :가장 간단한 형태의 RNN레이어, 활성화 함수로 tanh가 사용됨(tanh: -1 ~ 1 사이의 값을 반환)
# #### (2) LSTM(Long short Term Memory) : 입력 데이터와 출력 사이의 거리가 멀어질수로 연관 관계가 적어진다(Long Term Dependency,장기의존성 문제), LSTM은 장기 의존성 문제를 해결하기 위해 출력값외에 셀상태(cell state)값을 출력함, 활성화 함수로 tanh외에 sigmoid가 사용됨
# #### (3) GRU(Gated Recurent Unit) : 뉴욕대 조경현 교수 등이 제안, LSTM보다 구조가 간단하고 성능이 우수함

# %%
import tensorflow as tf
import numpy as np

# %%
# Sequence data
X = np.array([[0,1,2,3],
              [1,2,3,4],
              [2,3,4,5],
              [3,4,5,6],
              [4,5,6,7],
              [5,6,7,8]],dtype=np.float32)

x_data = tf.reshape(X,(-1,4,1))  # (6,4,1)

y_data = np.array([4,5,6,7,8,9],dtype=np.float32)

print(x_data.shape,y_data.shape)
# print(type(x_data),type(y_data))
x_data
# Out:
# (6, 4, 1) (6,)
# <tf.Tensor: shape=(6, 4, 1), dtype=float32, numpy=
# array([[[0.],
#         [1.],
#         [2.],
#         [3.]],
#
#        [[1.],
#         [2.],
#         [3.],
#         [4.]],
#
#        [[2.],
#         [3.],
#         [4.],
#         [5.]],
#
#        [[3.],
#         [4.],
#         [5.],
#         [6.]],
#
#        [[4.],
#         [5.],
#         [6.],
#         [7.]],
#
#        [[5.],
#         [6.],
#         [7.],
#         [8.]]], dtype=float32)>

# %% [markdown]
# ### [1]SimpleRNN
# #### 가장 간단한 형태의 RNN

# %%
# RNN 순환 신경망 구현:SimpleRNN
model= tf.keras.Sequential([
    # X:(N,D), Wx:(D,H), Wh:(H,H), b:H
    tf.keras.layers.SimpleRNN(units=300,return_sequences=True,input_shape=(4,1)),
    tf.keras.layers.SimpleRNN(units=300),
    tf.keras.layers.Dense(1)
])

# mean_squared_error(mse)
model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 4, 300)            90600
#
#  simple_rnn_7 (SimpleRNN)    (None, 300)               180300
#
#  dense_2 (Dense)             (None, 1)                 301
#
# =================================================================
# Total params: 271,201
# Trainable params: 271,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_data,y_data,epochs=100)
print(model.predict(x_data))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0045
# Epoch 2/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0042
# Epoch 3/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0041
# Epoch 4/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0040
# Epoch 5/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0038
# Epoch 6/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0037
# Epoch 7/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0037
# Epoch 8/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0035
# Epoch 9/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0034
# Epoch 10/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0033
# Epoch 11/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0031
# Epoch 12/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0031
# Epoch 13/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0030
# Epoch 14/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0029
# Epoch 15/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0028
# Epoch 16/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0027
# Epoch 17/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0026
# Epoch 18/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0026
# Epoch 19/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0025
# Epoch 20/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0024
# Epoch 21/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0024
# Epoch 22/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0023
# Epoch 23/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0023
# Epoch 24/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0022
# Epoch 25/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0021
# Epoch 26/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0021
# Epoch 27/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0020
# Epoch 28/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0020
# Epoch 29/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0020
# Epoch 30/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0019
# Epoch 31/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0019
# Epoch 32/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0018
# Epoch 33/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0018
# Epoch 34/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0017
# Epoch 35/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0017
# Epoch 36/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0017
# Epoch 37/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0016
# Epoch 38/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0016
# Epoch 39/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0016
# Epoch 40/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0016
# Epoch 41/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0015
# Epoch 42/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0015
# Epoch 43/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0015
# Epoch 44/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0014
# Epoch 45/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0014
# Epoch 46/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0014
# Epoch 47/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0014
# Epoch 48/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0014
# Epoch 49/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0013
# Epoch 50/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0013
# Epoch 51/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0013
# Epoch 52/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0013
# Epoch 53/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0013
# Epoch 54/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0012
# Epoch 55/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 56/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 57/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0012
# Epoch 58/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0012
# Epoch 59/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0012
# Epoch 60/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0012
# Epoch 61/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0012
# Epoch 62/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 63/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0011
# Epoch 64/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0011
# Epoch 65/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 66/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 67/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 68/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 69/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0011
# Epoch 70/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0011
# Epoch 71/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0011
# Epoch 72/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 73/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0011
# Epoch 74/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0010
# Epoch 75/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0010
# Epoch 76/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0010
# Epoch 77/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0010
# Epoch 78/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0010
# Epoch 79/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0010
# Epoch 80/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0010
# Epoch 81/100
# 1/1 [==============================] - 0s 20ms/step - loss: 9.9188e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 20ms/step - loss: 9.9053e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 31ms/step - loss: 9.7391e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 25ms/step - loss: 9.7472e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 22ms/step - loss: 9.6710e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 29ms/step - loss: 9.7376e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 23ms/step - loss: 9.6693e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.5884e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.4607e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 25ms/step - loss: 9.4527e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 24ms/step - loss: 9.3196e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 21ms/step - loss: 9.2178e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 23ms/step - loss: 9.2933e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 28ms/step - loss: 9.1914e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 25ms/step - loss: 9.1609e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 22ms/step - loss: 9.0310e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 21ms/step - loss: 8.9969e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.0364e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 23ms/step - loss: 8.9350e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.9528e-04
# 1/1 [==============================] - 0s 233ms/step
# [[3.9966238]
#  [5.020815 ]
#  [5.9601626]
#  [7.0089746]
#  [8.045018 ]
#  [8.965327 ]]

# %%
# 학습되지 않은 입력 데이터에 대한 예측 결과
print(model.predict(np.array([[[6.],[7.],[8.],[9.]]])))
print(model.predict(np.array([[[-1.],[0.],[1.],[2.]]])))
# 평가
model.evaluate(x_data, y_data)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[9.716539]]
# 1/1 [==============================] - 0s 20ms/step
# [[1.4890686]]
# 1/1 [==============================] - 0s 269ms/step - loss: 8.9018e-04
# 0.0008901755791157484

# %% [markdown]
# ### [2] LSTM(Long short Term Memory)
# #### 입력 데이터와 출력 사이의 거리가 멀어질수로 연관 관계가 적어진다(Long Term Dependency,장기의존성 문제)
# #### LSTM은 장기 의존성 문제를 해결하기 위해 출력값외에 셀상태(cell state)값을 출력함

# %%
model= tf.keras.Sequential([
    # X:(N,D), Wx:(D,H), Wh:(H,H), b:H
    tf.keras.layers.SimpleRNN(units=300,return_sequences=True,input_shape=(4,1)),
    tf.keras.layers.SimpleRNN(units=300),
    tf.keras.layers.Dense(1)
])

# mean_squared_error(mse)
model.compile(optimizer='adam',loss='mse')
model.summary()

# %% [markdown]
# ### [3] GRU(Gated Recurent Unit)
# #### 뉴욕대 조경현 교수 등이 제안, LSTM보다 구조가 간단하고 성능이 우수

# %%
# RNN 순환 신경망 구현  : GRU
model = tf.keras.Sequential([
    tf.keras.layers.GRU(units=300, return_sequences=True, input_shape=[4,1]),
    tf.keras.layers.GRU(units=300),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 4, 300)            272700
#
#  gru_1 (GRU)                 (None, 300)               541800
#
#  dense_3 (Dense)             (None, 1)                 301
#
# =================================================================
# Total params: 814,801
# Trainable params: 814,801
# Non-trainable params: 0
# _________________________________________________________________
